# %% [markdown]
# # Testing Scraper Sources
#
# * paperscraper [https://pypi.org/project/paperscraper/](https://pypi.org/project/paperscraper/) | Python package for web scraping metadata or full-text files from PubMed and servers: arXiv, medRxiv, bioRxiv, and chemRxiv. This will help us gain a deeper understanding beyond what PubMed’s API will give us and give us counts for citations, like in Google Scholar | Free- install the Python package and use it | 30,000 \- 400,000 papers | Depends on how many places we scrape from.
# * PRAW library (Python Reddit API Wrapper) for the Reddit API  [https://developers.reddit.com/docs/capabilities/server/reddit-api](https://developers.reddit.com/docs/capabilities/server/reddit-api) | This will help to support retrieving Reddit post data. It can scrape posts, comments, subreddits, users (data we will not use), and searches. | Free for non-commercial research use, though rate-limited | Around 1,000 posts. | Maybe 2 or 3 pulls, depending on the size of the data we want to pull.
# * General scraping tools like BeautifulSoup and Scrapy for online forums [https://beautiful-soup-4.readthedocs.io/en/latest/](https://beautiful-soup-4.readthedocs.io/en/latest/) [https://github.com/scrapy/scrapy](https://github.com/scrapy/scrapy)   | Beautiful Soup: Python package, HTML and XML parser. Scrapy: A web-scraping tool to extract structured data.  | Available as a Python package. Make sure to check the websites’ robots.txt before using | Around 1,000 posts. | Again, maybe 2 or 3 pulls.

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Paperscraper

# %%
# pip install paperscraper # use if new environment

# %%
from paperscraper.pubmed import get_pubmed_papers as get_pubmed

# %%
endo_papers = get_pubmed(query= "Endometriosis", max_results= 10)
endo_papers
# Out:
#                                                title  \
# 0  Altered miRNA cargo of endometrial extracellul...
# 1  RE-1 silencing transcription factor is reduced...
# 2  Endometrial BCL6 Expression and Reproductive O...
# 3  Endometriosis and Chronic Endometritis: Shared...
# 4  Correlations Between Ultrasound Features and H...
# 5  Endometriosis-Associated Infertility: A Review...
# 6  Emerging Non-Pharmacological Approaches in End...
# 7  Financial Toxicity in Women with Endometriosis...
# 8  TICAM1-Mediated TLR3/TLR4 Signaling Promotes E...
# 9  Translational Assessment of Omics Approaches i...
#
#                                             abstract  \
# 0  Could the miRNA cargo of extracellular vesicle...
# 1  Endometriosis is a steroid-dependent gynecolog...
# 2  Background/Objectives: Endometrial B-cell lymp...
# 3  Endometriosis (EM) and chronic endometritis (C...
# 4  Adenomyosis is a benign gynecologic condition ...
# 5  Background: Endometriosis affects 10-15% of re...
# 6  Background/Objectives: Endometriosis is a chro...
# 7  Endometriosis is a chronic condition associate...
# 8  Endometriosis (EMs) is an estrogen-dependent i...
# 9  Endometriosis affects an estimated 5-10% of wo...
#
#                                        journal        date  \
# 0                      Human reproduction open  2026-06-12
# 1    bioRxiv : the preprint server for biology  2026-06-12
# 2             Diagnostics (Basel, Switzerland)  2026-06-12
# 3             Diagnostics (Basel, Switzerland)  2026-06-12
# 4             Diagnostics (Basel, Switzerland)  2026-06-12
# 5                 Journal of clinical medicine  2026-06-12
# 6                 Journal of clinical medicine  2026-06-12
# 7              Healthcare (Basel, Switzerland)  2026-06-12
# 8  International journal of molecular sciences  2026-06-12
# 9  International journal of molecular sciences  2026-06-12
#
#                                              authors  \
# 0  [AlbaBas-Rivas, AdriánVillalba, AitanaMerino-P...
# 1  [PaigeMinchella, AyushiVashisht, RileyPeterson...
# 2  [Ana MariaMihoci, DemetraSocolov, Olga OdettaD...
# 3                     [SiqiBai, ZihanZhou, HongZhan]
# 4  [Melinda-IldikoMitranovici, DanCostachescu, Se...
# 5  [MagdalenaGniadek, AlinaPorubenska, KarolinaPe...
# 6  [IgaSzukalska, MaciejZiętek, EdytaZagrodnik, M...
# 7  [KatarzynaPietrzak, Anna WeronikaSzablewska, A...
# 8  [HaLiSaiMuDanLiFu, SumingHuang, YameiLi, YanLi...
# 9  [IvanSalido-Guadarrama, OliverCruz-Orozco, Ign...
#
#                            doi
# 0       10.1093/hropen/hoag040
# 1   10.64898/2026.05.30.728827
# 2  10.3390/diagnostics16111714
# 3  10.3390/diagnostics16111648
# 4  10.3390/diagnostics16111586
# 5          10.3390/jcm15114297
# 6          10.3390/jcm15114136
# 7   10.3390/healthcare14111449
# 8         10.3390/ijms27115089
# 9         10.3390/ijms27114888

# %%
type(endo_papers)
# Out:
# pandas.core.frame.DataFrame

# %%
endo_papers["abstract"][0]
# Out:
# "Could the miRNA cargo of extracellular vesicles (EVs) secreted by eutopic endometrium from women with endometriosis be involved in the pregnancy complications related to endometriosis?\nEVs secreted by eutopic endometrium from women with endometriosis present altered miRNA that modulates biological processes related to pregnancy disorders.\nCommunication between endometrial cells, immune cells, endothelial cells, and the embryo is essential for the correct establishment and development of pregnancy, and EVs have been proposed as key mediators of this dialogue. This study aimed to elucidate whether EV-mediated communication is altered in endometriosis, by analysing the miRNA cargo of EVs secreted by eutopic endometrium from women with endometriosis, after differentiation to the gestational phase, compared with the miRNA cargo of EVs secreted by eutopic endometrium from healthy women, also after differentiation to the gestational phase.\nThis was a prospective experimental comparative study in which endometrial organoids were derived from eutopic endometrium of patients with endometriosis (n\u2009=\u200916) and healthy women (n\u2009=\u200915).\nOrganoids were differentiated to mimic the gestational phase through supplementation with pregnancy hormones. EVs were then isolated from the culture medium, characterized, and their miRNA cargo was profiled by sequencing. Target genes of the significantly differentially expressed miRNAs were identified, and functional enrichment analysis was subsequently performed. Finally, the organoids were co-cultured with human endometrial stromal cells (hESCs) and human placental choriocarcinoma JAR cells, and the effects of EV-derived miRNAs were assessed by qPCR using representative target genes selected based on their roles in endometrium-embryo communication and epithelial-mesenchymal and mesenchymal-epithelial transitions (EMT-MET) in organoids, EMT in stromal (hESC) cells, and endometrium-embryo communication in JAR cells.\nEVs were successfully isolated. miRNA-seq showed eight significantly differentially expressed miRNAs (false discovery rate [FDR] < 0.05); six were downregulated: miR-1290, miR-1246, miR-320d, miR-4516, miR-12136, and miR-3065-5p; and two were upregulated: miR-191-5p, and miR-335-5p. These miRNAs target 3964 genes and GO enrichment analysis identified 789 biological processes (FDR < 0.05), mainly involved in embryo development and developmental growth, immune system function, angiogenesis, and epithelial-mesenchymal transition. KEGG pathway analysis revealed 32 deregulated pathways (FDR < 0.05), including the PI3K-Akt pathway commonly related to the pathogenesis of preeclampsia. Validation in gestational epithelial endometriosis organoids showed upregulation of IGF2 and NR2F2, and downregulation of LIF. Within the EMT-MET group, PTK2B was downregulated, whereas WASF3 and RAC1 were upregulated. In hESC cells co-cultured with gestational epithelial endometriosis organoids, SFRP1, CDC42, RAC1, and WASF3 were upregulated, while PTK2B was downregulated, reflecting the miRNA cargo of ENDO-GEST-derived EVs. Similarly, in JAR cells co-cultured with gestational epithelial endometriosis, NR2F2 and IGF2 were upregulated, whereas MDFI, SP3, and RDH10 were downregulated. All results were consistent with the inverse expression patterns of their regulatory miRNAs in secreted EVs.\nAll raw sequencing data are available through the Gene Expression Omnibus (GEO) under accession number GSE302961.\nThis was an in vitro study in which the conditions of the endometrial organoid culture could not fully replicate the intrauterine environment. In addition, due to the limited amount of RNA obtained from EVs, sample pooling was required for downstream analyses, which may have reduced our ability to assess inter-sample variability.\nEVs secreted by eutopic endometrium from women with endometriosis present altered miRNA that modulates processes essential for a successful pregnancy and could serve as p ...

# %% [markdown]
# We are able to get the full abstract of papers, which will help with text analysis. Paperscraper already has keyword searching for us, though!

# %% [markdown]
# ## Reddit's PRAW library
# https://praw.readthedocs.io/en/latest/getting_started/quick_start.html

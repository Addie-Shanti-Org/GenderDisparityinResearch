# %%
import requests
import json

# %%
api_key = "e0697d96a0aa8cb9fcaad8031c64b151"
url = "https://api.elsevier.com/content/search/scopus"

headers = {"X-ELS-APIKey": "e0697d96a0aa8cb9fcaad8031c64b151", "Accept": "application/json"}

query_params = {"query": "TITLE-ABS-KEY(pregnancy OR endometriosis) AND PUBYEAR > 2000 AND PUBYEAR < 2026",
                "count": 25,
                "view": "STANDARD"}

# %%
response = requests.get(url, headers = headers, params = query_params)

# %%
if response.status_code == 200:
    data = response.json()
    search_results = data.get('search-results', {}).get('entry', [])
    
    print(search_results)

    for article in search_results:
        title = article.get('dc:title')
        creator = article.get('dc:creator')
        cover_date = article.get('prism:coverDate')
        doi = article.get('prism:doi')
        abstract = article.get('dc:description', 'No Access')

        print(f"Title: {title}")
        print(f"Author: {creator}")
        print(f"Date: {cover_date}")
        print(f"DOI: {doi}")
        print(f"Abstract: {abstract}")

else:
    print(f"Error {response.status_code}")
# Out:
# [{'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105012932299'}, {'@_fa': 'true', '@ref': 'author-affiliation', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105012932299?field=author,affiliation'}, {'@_fa': 'true', '@ref': 'scopus', '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=105012932299&origin=inward'}, {'@_fa': 'true', '@ref': 'scopus-citedby', '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=105012932299&origin=inward'}], 'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/105012932299', 'dc:identifier': 'SCOPUS_ID:105012932299', 'eid': '2-s2.0-105012932299', 'dc:title': 'Clinical value of elevated miR-142-3p in subclinical hypothyroidism during the second trimester of pregnancy', 'dc:creator': 'He W.', 'prism:publicationName': 'Gynecological Endocrinology', 'prism:issn': '09513590', 'prism:eIssn': '14730766', 'prism:volume': '41', 'prism:issueIdentifier': '1', 'prism:pageRange': None, 'prism:coverDate': '2025-12-31', 'prism:coverDisplayDate': '31 December 2025', 'prism:doi': '10.1080/09513590.2025.2533482', 'citedby-count': '0', 'affiliation': [{'@_fa': 'true', 'affilname': 'Zhangjiakou First Hospital', 'affiliation-city': 'Zhangjiakou', 'affiliation-country': 'China'}], 'pubmed-id': '40773206', 'prism:aggregationType': 'Journal', 'subtype': 'ar', 'subtypeDescription': 'Article', 'article-number': '2533482', 'source-id': '26117', 'openaccess': '1', 'openaccessFlag': True, 'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}, {'$': 'repository'}, {'$': 'repositoryam'}]}, 'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}, {'$': 'Green'}]}}, {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105028127847'}, {'@_fa': 'true', '@ref': 'author-affiliation', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105028127847?field=author,affiliation'}, {'@_fa': 'true', '@ref': 'scopus', '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=105028127847&origin=inward'}, {'@_fa': 'true', '@ref': 'scopus-citedby', '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=105028127847&origin=inward'}], 'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/105028127847', 'dc:identifier': 'SCOPUS_ID:105028127847', 'eid': '2-s2.0-105028127847', 'dc:title': 'Determinants of Unwanted Pregnancies Among Pregnant Women Attending Primary Health Care Centres in Kirkuk, Iraq: A Cross-Sectional Study', 'dc:creator': 'Shakiri A.N.', 'prism:publicationName': 'Babcock University Medical Journal', 'prism:issn': '24656666', 'prism:eIssn': '27564657', 'prism:volume': '8', 'prism:issueIdentifier': '2', 'prism:pageRange': '282-288', 'prism:coverDate': '2025-12-31', 'prism:coverDisplayDate': '31 December 2025', 'prism:doi': '10.38029/babcockuniv.med.j..v8i2.1060', 'citedby-count': '0', 'affiliation': [{'@_fa': 'true', 'affilname': 'University of Kirkuk', 'affiliation-city': 'Kirkuk', 'affiliation-country': 'Iraq'}], 'prism:aggregationType': 'Journal', 'subtype': 'ar', 'subtypeDescription': 'Article', 'source-id': '21101176727', 'openaccess': '1', 'openaccessFlag': True, 'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}, {'$': 'repository'}, {'$': 'repositoryam'}]}, 'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}, {'$': 'Green'}]}}, {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105012946030'}, {'@_fa': 'true', '@ref': 'author-affiliation', '@href': 'https://api.elsevier.com/content/abstract/scopus_id/105012946030?field=author,affiliation'}, {'@_fa': 'true', '@ref': 'scopus', '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=105012946030&origin=inward'}, {'@_fa': 'true', '@ref': 'scopus-citedby', '@href': 'ht ...
# Title: Clinical value of elevated miR-142-3p in subclinical hypothyroidism during the second trimester of pregnancy
# Author: He W.
# Date: 2025-12-31
# DOI: 10.1080/09513590.2025.2533482
# Abstract: No Access
# Title: Determinants of Unwanted Pregnancies Among Pregnant Women Attending Primary Health Care Centres in Kirkuk, Iraq: A Cross-Sectional Study
# Author: Shakiri A.N.
# Date: 2025-12-31
# DOI: 10.38029/babcockuniv.med.j..v8i2.1060
# Abstract: No Access
# Title: A Rare Case of Actinomycetoma In Pregnancy: Effective Treatment with the Combination of Amoxicillin-Clavulanic Acid
# Author: Hidayah R.M.N.
# Date: 2025-12-31
# DOI: 10.2147/IJWH.S527336
# Abstract: No Access
# Title: The effectiveness of etoposide-containing chemotherapy regimens in the initial treatment of Hemophagocytic Syndrome in pregnancy
# Author: Wang J.
# Date: 2025-12-31
# DOI: 10.1080/16078454.2025.2538307
# Abstract: No Access
# Title: Ectopic pregnancy — a comparison of treatment methods in terms of effectiveness and impact on fertility
# Author: Zieba W.
# Date: 2025-12-31
# DOI: 10.5603/gpl.101849
# Abstract: No Access
# Title: Childbirth outcomes in rape-related pregnancies: a comparative study of women receiving care in a birthing room designed to promote person-centredness in eastern Democratic Republic of Congo
# Author: Berg U.
# Date: 2025-12-31
# DOI: 10.1080/16549716.2025.2541535
# Abstract: No Access
# Title: Diagnostic Accuracy of Ultrasonography in Detection of Molar Pregnancy Keeping Histopathology As Gold Standarddrome: A Case Report
# Author: Amin M.
# Date: 2025-12-31
# DOI: 10.54079/jpmi.39.4.3769
# Abstract: No Access
# Title: An Increased Plasma D-Dimer Levels During Different Stages of Normal and Complicated Pregnancies Among Women in Bisha, Saudi Arabia
# Author: Belali T.M.
# Date: 2025-12-31
# DOI: 10.2147/JBM.S523353
# Abstract: No Access
# Title: On-farm Non-Invasive Pregnancy Diagnosis of Doe (Capra Hircus) using Barium Chloride
# Author: Catalonia H.M.D.
# Date: 2025-12-31
# DOI: 10.47278/journal.ijab/2025.104
# Abstract: No Access
# Title: Comparison of bleeding and tubal rupture rates after use of tranexamic acid with methotrexate in treatment of ectopic pregnancy
# Author: Demir A.R.A.
# Date: 2025-12-31
# DOI: 10.52142/omujecm.42.4.12
# Abstract: No Access
# Title: Expanded Histologic Lineage and Origin of Mesonephric-Like Adenocarcinoma: A Clinicopathologic Study of 9 Cases
# Author: Shi Y.
# Date: 2025-12-31
# DOI: 10.1097/PGP.0000000000001154
# Abstract: No Access
# Title: TRENDS IN PRE-PREGNANCY BODY MASS INDEX AND GESTATIONAL WEIGHT GAIN AMONG PREGNANT WOMEN IN CROATIA
# Author: Vince K.
# Date: 2025-12-31
# DOI: 10.20471/acc.2025.64.04.06
# Abstract: No Access
# Title: A Delayed Metastatic Storm after Molar Pregnancy: CT Chest and Brain Findings of Choriocarcinoma with Life-Threatening Hemoptysis
# Author: Khairo M.
# Date: 2025-12-31
# DOI: 10.3941/jrcr.5879
# Abstract: No Access
# Title: In Vitro Fertilization and Dichorionic-Diamniotic Twin Pregnancies in Nulliparous Women: A Retrospective Cohort Study Comparing Pregnancy Outcomes Between Advanced and Younger Maternal Age Groups
# Author: He M.P.
# Date: 2025-12-31
# DOI: 10.2147/IJWH.S538630
# Abstract: No Access
# Title: Impact of high-normal TSH in early pregnancy on gestational diabetes mellitus: a retrospective cohort study
# Author: Yang L.
# Date: 2025-12-31
# DOI: 10.1080/14767058.2025.2540464
# Abstract: No Access
# Title: Urgency Or Emergency; Effective Management Of Hypertensive Crisis In Pregnancy
# Author: Jamil M.
# Date: 2025-12-31
# DOI: 10.37939/jrmc.v29i4.2924
# Abstract: No Access
# Title: Maternal and Fetal Outcomes in Mothers with Intrahepatic Cholestasis of Pregnancy Compared to Healthy Pregnant Women: A Case-Control Study
# Author: Jafarei R.M.
# Date: 2025-12-31
# DOI: 10.5812/semj-163163
# Abstract: No Access
# Title: Hypertensive Disorders of Pregnancy Across the Range of Gravidity
# Author: Naveed P.
# Date: 2025-12-31
# DOI: 10.54079/jpmi.39.4.3637
# Abstract: No Access
# Title: Multidisciplinary team approach of treatment of a metastatic gastric carcinoma during pregnancy: a case report
# Author: Eijsink J.F.H.
# Date: 2025-12-31
# DOI: 10.21037/jgo-2025-288
# Abstract: No Access
# Title: Pregnancy Outcomes Following Assisted Reproductive Technology in Advanced Maternal Age Primiparous Women: A Retrospective Cohort Study
# Author: Deng Q.
# Date: 2025-12-31
# DOI: 10.2147/IJWH.S538128
# Abstract: No Access
# Title: METHOTREXATE TREATMENT OF ECTOPIC TUBAL PREGNANCY
# Author: Tučkar N.
# Date: 2025-12-31
# DOI: 10.20471/acc.2025.64.04.14
# Abstract: No Access
# Title: Workload, Musculoskeletal Pain, and Quality of Life in Pregnant and Postpartum Women: A Prospective Cohort Study
# Author: Kulkarni S.D.
# Date: 2025-12-31
# DOI: 10.1097/JOM.0000000000003655
# Abstract: No Access
# Title: Comparison of APOBEC3 C levels in pregnant women infected with hMPV
# Author: Madfoon Z.M.
# Date: 2025-12-31
# DOI: 10.24321/0019.5138.2026103
# Abstract: No Access
# Title: The influence of SARS-CoV-2 vaccination on in vitro fertilization outcomes
# Author: Heusler A.A.
# Date: 2025-12-31
# DOI: 10.1080/21645515.2025.2541495
# Abstract: No Access
# Title: Sodium Acetate Attenuates Fructose-Induced Mitochondrial Dysfunction and Cardiometabolic Disorders in Pregnant Wistar Rats
# Author: Oyabambi O.
# Date: 2025-12-31
# DOI: 10.54548/njps.v40i2.15
# Abstract: No Access
